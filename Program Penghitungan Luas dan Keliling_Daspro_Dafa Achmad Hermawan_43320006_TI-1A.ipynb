# %%
i=0
#Membuat Fungsi
def Luas_Persegi(sisi):
    luasP = sisi * sisi
    return luasP
def Luas_Persegi_Panjang(panjang,lebar):
    luasPP = panjang * lebar
    return luasPP
def Luas_Jajargenjang(alas,tinggi):
    luasJG = alas * tinggi
    return luasJG
def Luas_Segitiga(alas,tinggi):
    luasS = alas * tinggi / 2
    return luasS
def Luas_Lingkaran(r):
    luasL = 22 / 7 * r ** 2
    return luasL
def Keliling_Persegi(sisi):
    kelilingP = 4 * sisi
    return kelilingP
def Keliling_Persegi_Panjang(panjang,lebar):
    kelilingPP = 2 * lebar + 2 * tinggi
    return kelilingPP
def Keliling_Jajargenjang(A,B):
    kelilingJG = 2 * sisiA + 2 * sisiB
    return kelilingJG
def Keliling_Segitiga(sisiA,sisiB,sisiC):
    kelilingS = sisiA + sisiB + sisiC
    return kelilingS 
def Keliling_Lingkaran(r):
    kelilingL = 2 * 22 / 7 * r
    return kelilingL
#Membuat program
print('=============================================================================================================')
print('                             Program Penghitungan Luas & Keliling Bangun Datar')
print('=============================================================================================================')
print('')
print('Pilih apa yang ingin dihitung!')
print('')
print('1. Luas')
print('2. Keliling')
print('')
choice = int(input('Masukkan pilihan Anda: '))
if choice == 1:
    pilihan = 1
    while pilihan != 0:
        print('')
        print ('Pilih jenis bangun datar yang ingin dihitung!')
        print('1. Persegi')
        print('2. Persegi panjang')
        print('3. Jajargenjang')
        print('4. Segitiga')
        print('5. Lingkaran')
        print('')
        pilihan = int(input('Masukkan pilihan Anda: '))
        if pilihan == 1:
            print('=========================== Luas Persegi ===========================')
            print('')
            sisi = float(input('Masukkan sisi persegi : '))
            print('')
            print('')
            print('Luas Persegi adalah: ', Luas_Persegi(sisi))
            print('')
            print('')
        elif pilihan == 2:
            print('======================= Luas Persegi Panjang =======================')
            print('')
            lebar = float(input('Masukkan lebar: '))
            panjang = float(input('Masukkan panjang: '))
            print('')
            print('')
            print('Luas Persegi Panjang adalah: ', Luas_Persegi_Panjang(panjang,lebar))
            print('')
            print('')
        elif pilihan == 3:
            print('========================= Luas Jajargenjang =========================')
            print('')
            alas = float(input('Masukkan lebar alas: '))
            tinggi = float(input('Masukkan tinggi: '))
            print('')
            print('')
            print('Luas Jajargenjang adalah: ', Luas_Jajargenjang(alas,tinggi))
            print('')
            print('')
        elif pilihan == 4:
            print('=========================== Luas Segitiga ===========================')
            print('')
            alas = float(input('Masukkan lebar alas: '))
            tinggi = float(input('Masukkan tinggi: '))
            print('')
            print('')
            print('Luas Segitiga adalah: ', Luas_Segitiga(alas,tinggi))
            print('')
            print('')
        elif pilihan == 5:
            print('========================= Luas Lingkaran =========================')
            print('')
            r = float(input('Masukkan lebar jari-jari: '))
            print('')
            print('')
            print('Luas lingkaran adalah: ', Luas_Lingkaran(r))
            print('')
            print('')
        else:
            print('InputSalah')
        break
elif choice == 2:
    pilihan = 1
    while pilihan != 0:
        print('')
        print ('Pilih jenis bangun datar yang ingin dihitung!')
        print('1. Persegi')
        print('2. Persegi panjang')
        print('3. Jajargenjang')
        print('4. Segitiga')
        print('5. Lingkaran')
        print('')
        pilihan = int(input('Masukkan pilihan Anda: '))
        if pilihan == 1:
            print('=========================== Keliling Persegi ===========================')
            print('')
            sisi = float(input('Masukkan sisi persegi : '))
            print('')
            print('')
            print('Keliling Persegi adalah: ', Keliling_Persegi(sisi))
            print('')
            print('')
        elif pilihan == 2:
            print('======================= Keliling Persegi Panjang =======================')
            print('')
            lebar = float(input('Masukkan lebar: '))
            panjang = float(input('Masukkan panjang: '))
            print('')
            print('')
            print('Keliling Persegi Panjang adalah: ', Keliling_Persegi_Panjang(panjang,lebar))
            print('')
            print('')
        elif pilihan == 3:
            print('========================= Keliling Jajargenjang =========================')
            print('')
            A = float(input('Masukkan panjang sisi A: '))
            B = float(input('Masukkan panjang sisi B: '))
            print('')
            print('')
            print('Keliling Jajargenjang adalah: ', Keliling_Jajargenjang(A,B))
            print('')
            print('')
        elif pilihan == 4:
            print('=========================== Keliling Segitiga ===========================')
            print('')
            sisiA = float(input('Masukkan panjang sisi A: '))
            sisiB = float(input('Masukkan panjang sisi B: '))
            sisiC = float(input('Masukkan panjang sisi C: '))
            print('')
            print('')
            print('Keliling Segitiga adalah: ', Keliling_Segitiga(sisiA,sisiB,sisiC))
            print('')
            print('')
        elif pilihan == 5:
            print('========================= Keliling Lingkaran =========================')
            print('')
            r = float(input('Masukkan lebar jari-jari: '))
            print('')
            print('')
            print('Keliling lingkaran adalah: ', Keliling_Lingkaran(r))
            print('')
            print('')
        else:
            print('InputSalah')
        break
else:
    print('InputSalah')
# Out:
# ...
#                              Program Penghitungan Luas & Keliling Bangun Datar
# ...
#
# Pilih apa yang ingin dihitung!
#
# 1. Luas
# 2. Keliling
#
#
# Pilih jenis bangun datar yang ingin dihitung!
# 1. Persegi
# 2. Persegi panjang
# 3. Jajargenjang
# 4. Segitiga
# 5. Lingkaran
#
# =========================== Luas Persegi ===========================
#
#
#
# Luas Persegi adalah:  144.0
